# %% [markdown]
# # บทที่ 4t (3/3) - ข้อมูลอนุกรมเวลา - Time-series data
#
# อ.ดร.ธนชาตย์ ฤทธิ์บำรุง (อ.เชค)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ai-builders/curriculum/blob/main/notebooks/04t_03_time_series.ipynb)

# %%
# !pip install fbprophet
# Out:
# Collecting fbprophet
#   Downloading fbprophet-0.7.1.tar.gz (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Cython>=0.22 in /usr/local/lib/python3.12/dist-packages (from fbprophet) (3.0.12)
# Collecting cmdstanpy==0.9.5 (from fbprophet)
#   Downloading cmdstanpy-0.9.5-py3-none-any.whl.metadata (2.9 kB)
# Collecting pystan>=2.14 (from fbprophet)
#   Downloading pystan-3.10.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.12/dist-packages (from fbprophet) (2.0.2)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from fbprophet) (2.2.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from fbprophet) (3.10.0)
# Collecting LunarCalendar>=0.0.9 (from fbprophet)
#   Downloading LunarCalendar-0.0.9-py2.py3-none-any.whl.metadata (6.3 kB)
# Collecting convertdate>=2.1.2 (from fbprophet)
#   Downloading convertdate-2.4.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: holidays>=0.10.2 in /usr/local/lib/python3.12/dist-packages (from fbprophet) (0.88)
# Collecting setuptools-git>=1.2 (from fbprophet)
#   Downloading setuptools_git-1.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from fbprophet) (2.9.0.post0)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.12/dist-packages (from fbprophet) (4.67.1)
# Collecting pymeeus<=1,>=0.3.13 (from convertdate>=2.1.2->fbprophet)
#   Downloading PyMeeus-0.5.12.tar.gz (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 63.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ephem>=3.7.5.3 (from LunarCalendar>=0.0.9->fbprophet)
#   Downloading ephem-4.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from LunarCalendar>=0.0.9->fbprophet) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->fbprophet) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->fbprophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->fbprophet) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->fbprophet) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->fbprophet) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->fbprophet) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->fbprophet) (3.3.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.4->fbprophet) (2025.3)
# Requirement already satisfied: aiohttp<4.0,>=3.6 in /usr/local/lib/python3.12/dist-packages (from pystan>=2.14->fbprophet) (3.13.3)
# Collecting clikit<0.7,>=0.6 (from pystan>=2.14->fbprophet)
#   Downloading clikit-0.6.2-py2.py3-none-any.whl.metadata (1.6 kB)
# Collecting httpstan<4.14,>=4.13 (from pystan>=2.14->fbprophet)
#   Downloading httpstan-4.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Collecting pysimdjson<7,>=5.0.2 (from pystan>=2.14->fbprophet)
#   Downloading pysimdjson-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from pystan>=2.14->fbprophet) (75.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->fbprophet) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (1.22.0)
# Collecting crashtest<0.4.0,>=0.3.0 (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet)
#   Downloading crashtest-0.3.1-py3-none-any.whl.metadata (748 bytes)
# Collecting pastel<0.3.0,>=0.2.0 (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet)
#   Downloading pastel-0.2.1-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting pylev<2.0,>=1.3 (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet)
#   Downloading pylev-1.4.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting appdirs<2.0,>=1.4 (from httpstan<4.14,>=4.13->pystan>=2.14->fbprophet)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting marshmallow<4.0,>=3.10 (from httpstan<4.14,>=4.13->pystan>=2.14->fbprophet)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting webargs<9.0,>=8.0 (from httpstan<4.14,>=4.13->pystan>=2.14->fbprophet)
#   Downloading webargs-8.7.1-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (4.15.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (3.11)
# Downloading cmdstanpy-0.9.5-py3-none-any.whl (37 kB)
# Downloading convertdate-2.4.0-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 kB 4.2 MB/s eta 0:00:00
# Downloading LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Downloading pystan-3.10.0-py3-none-any.whl (13 kB)
# Downloading setuptools_git-1.2-py2.py3-none-any.whl (10 kB)
# Downloading clikit-0.6.2-py2.py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 5.9 MB/s eta 0:00:00
# Downloading ephem-4.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 62.8 MB/s eta 0:00:00
# Downloading httpstan-4.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (45.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 MB 15.7 MB/s eta 0:00:00
# Downloading pysimdjson-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 79.1 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading crashtest-0.3.1-py3-none-any.whl (7.0 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.7 MB/s eta 0:00:00
# Downloading pastel-0.2.1-py2.py3-none-any.whl (6.0 kB)
# Downloading pylev-1.4.0-py2.py3-none-any.whl (6.1 kB)
# Downloading webargs-8.7.1-py3-none-any.whl (32 kB)
# Building wheels for collected packages: fbprophet, pymeeus
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for fbprophet (setup.py) ... error
#   ERROR: Failed building wheel for fbprophet
#   Running setup.py clean for fbprophet
#   Building wheel for pymeeus (setup.py) ... done
#   Created wheel for pymeeus: filename=PyMeeus-0.5.12-py3-none-any.whl size=732000 sha256=b52b4ca1111015832b7bbbd4f11646df5852f1fb90676c51cff13aac23b9ea21
#   Stored in directory: /root/.cache/pip/wheels/92/74/5d/5cf1193a619dc315b5b0a158876900e21440c71130251307b6
# Successfully built pymeeus
# Failed to build fbprophet
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (fbprophet)

# %% [markdown]
# **เป้าหมายการเรียนรู้**
# 1. เข้าใจถึงองค์ประกอบของข้อมูลประเภทอนุกรมเวลา
# 2. สร้าง Forecasting Model เพื่อใช้ทำนายข้อมูลในอนาคตได้

# %% [markdown]
# *   ข้อมูลอนุกรมเวลา หรือ time-series data เป็นข้อมูลประเภทที่มีเวลากำกับอยู่
# *   ข้อมูลในการทำการวิเคราะห์ส่วนมากจะถูกจัดเก็บอยู่ในรูปแบบของอนุกรมเวลา
# *   การวิเคราะห์ที่นิยมมากสำหรับข้อมูลอนุกรมเวลา คือ การพยากรณ์ค่าในอนาคต
# *   สิ่งที่นิยมพยากรณ์กันในธุรกิจ คือ การพยากรณ์ยอดขาย
# *   ในข้อมูลอนุกรมเวลานั้น ประกอบด้วย 4 องค์ประกอบ
# *   Trend เป็นส่วนที่แสดงถึงทิศทางการเปลี่ยนแปลง
# *   Seasonal เป็นส่วนที่แสดงถึงการเปลี่ยนแปลงที่เป็นรูปแบบเดิมในช่วงสั้น
# *   Cyclical เป็นส่วนที่แสดงถึงการเปลี่ยนแปลงที่เป็นรูปแบบเดิมในช่วงระยะยาว (มากกว่า 1 ปี)
# *   Irregular เป็นส่วนที่เกิดขึ้นแบบสุ่ม คาดการณ์หรือพยากรณ์ไม่ได้

# %% [markdown]
# <img src=https://github.com/ai-builders/curriculum/raw/main/images/tabular_images/24.png width="1000px">

# %% [markdown]
# # Prophet Module

# %% [markdown]
# ในการวิเคราะห์ข้อมูลอนุกรมเวลา หรือ การพยากรณ์ข้อมูลนั้น เราจะใช้ Prophet Module ที่ถูกพัฒนาขึ้นโดย Facebook

# %%
# !pip install prophet
# Out:
# Collecting fbprophet
#   Downloading fbprophet-0.7.1.tar.gz (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Cython>=0.22 in /usr/local/lib/python3.12/dist-packages (from fbprophet) (3.0.12)
# Collecting cmdstanpy==0.9.5 (from fbprophet)
#   Downloading cmdstanpy-0.9.5-py3-none-any.whl.metadata (2.9 kB)
# Collecting pystan>=2.14 (from fbprophet)
#   Downloading pystan-3.10.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.12/dist-packages (from fbprophet) (2.0.2)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from fbprophet) (2.2.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from fbprophet) (3.10.0)
# Collecting LunarCalendar>=0.0.9 (from fbprophet)
#   Downloading LunarCalendar-0.0.9-py2.py3-none-any.whl.metadata (6.3 kB)
# Collecting convertdate>=2.1.2 (from fbprophet)
#   Downloading convertdate-2.4.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: holidays>=0.10.2 in /usr/local/lib/python3.12/dist-packages (from fbprophet) (0.88)
# Collecting setuptools-git>=1.2 (from fbprophet)
#   Downloading setuptools_git-1.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from fbprophet) (2.9.0.post0)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.12/dist-packages (from fbprophet) (4.67.1)
# Collecting pymeeus<=1,>=0.3.13 (from convertdate>=2.1.2->fbprophet)
#   Downloading PyMeeus-0.5.12.tar.gz (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 63.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ephem>=3.7.5.3 (from LunarCalendar>=0.0.9->fbprophet)
#   Downloading ephem-4.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from LunarCalendar>=0.0.9->fbprophet) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->fbprophet) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->fbprophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->fbprophet) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->fbprophet) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->fbprophet) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->fbprophet) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->fbprophet) (3.3.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.4->fbprophet) (2025.3)
# Requirement already satisfied: aiohttp<4.0,>=3.6 in /usr/local/lib/python3.12/dist-packages (from pystan>=2.14->fbprophet) (3.13.3)
# Collecting clikit<0.7,>=0.6 (from pystan>=2.14->fbprophet)
#   Downloading clikit-0.6.2-py2.py3-none-any.whl.metadata (1.6 kB)
# Collecting httpstan<4.14,>=4.13 (from pystan>=2.14->fbprophet)
#   Downloading httpstan-4.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Collecting pysimdjson<7,>=5.0.2 (from pystan>=2.14->fbprophet)
#   Downloading pysimdjson-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from pystan>=2.14->fbprophet) (75.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->fbprophet) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (1.22.0)
# Collecting crashtest<0.4.0,>=0.3.0 (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet)
#   Downloading crashtest-0.3.1-py3-none-any.whl.metadata (748 bytes)
# Collecting pastel<0.3.0,>=0.2.0 (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet)
#   Downloading pastel-0.2.1-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting pylev<2.0,>=1.3 (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet)
#   Downloading pylev-1.4.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting appdirs<2.0,>=1.4 (from httpstan<4.14,>=4.13->pystan>=2.14->fbprophet)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting marshmallow<4.0,>=3.10 (from httpstan<4.14,>=4.13->pystan>=2.14->fbprophet)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting webargs<9.0,>=8.0 (from httpstan<4.14,>=4.13->pystan>=2.14->fbprophet)
#   Downloading webargs-8.7.1-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (4.15.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (3.11)
# Downloading cmdstanpy-0.9.5-py3-none-any.whl (37 kB)
# Downloading convertdate-2.4.0-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 kB 4.2 MB/s eta 0:00:00
# Downloading LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Downloading pystan-3.10.0-py3-none-any.whl (13 kB)
# Downloading setuptools_git-1.2-py2.py3-none-any.whl (10 kB)
# Downloading clikit-0.6.2-py2.py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 5.9 MB/s eta 0:00:00
# Downloading ephem-4.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 62.8 MB/s eta 0:00:00
# Downloading httpstan-4.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (45.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 MB 15.7 MB/s eta 0:00:00
# Downloading pysimdjson-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 79.1 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading crashtest-0.3.1-py3-none-any.whl (7.0 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.7 MB/s eta 0:00:00
# Downloading pastel-0.2.1-py2.py3-none-any.whl (6.0 kB)
# Downloading pylev-1.4.0-py2.py3-none-any.whl (6.1 kB)
# Downloading webargs-8.7.1-py3-none-any.whl (32 kB)
# Building wheels for collected packages: fbprophet, pymeeus
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for fbprophet (setup.py) ... error
#   ERROR: Failed building wheel for fbprophet
#   Running setup.py clean for fbprophet
#   Building wheel for pymeeus (setup.py) ... done
#   Created wheel for pymeeus: filename=PyMeeus-0.5.12-py3-none-any.whl size=732000 sha256=b52b4ca1111015832b7bbbd4f11646df5852f1fb90676c51cff13aac23b9ea21
#   Stored in directory: /root/.cache/pip/wheels/92/74/5d/5cf1193a619dc315b5b0a158876900e21440c71130251307b6
# Successfully built pymeeus
# Failed to build fbprophet
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (fbprophet)

# %%
# !pip install prophet

# %%
# Load module ที่เราต้องการใช้ทั้งหมด

import pandas as pd
import matplotlib.pyplot as plt
from prophet import Prophet
from prophet.plot import add_changepoints_to_plot

# %%
# อ่านไฟล์ข้อมูลที่ต้องการวิเคราะห์

url = 'https://github.com/ai-builders/curriculum/raw/main/data/bangkok-air-quality.csv'
df = pd.read_csv(url)

# %%
# แสดงผลตัวอย่างข้อมูล

df.head(5)
# Out:
#        date  pm25  pm10   o3  no2  so2  co
# 0  2022/2/1    68    31    9    4
# 1  2022/2/2    58    35   10    6
# 2  2022/2/3    66    37   15   11
# 3  2022/2/4    73    48   17   15    1
# 4  2022/2/5    94    54   21   13    1

# %%
# ตรวจสอบ data types จะพบว่า คอลัมน์ date ถูกมองว่าเป็น string หรือ text

df.dtypes
# Out:
# date     object
#  pm25    object
#  pm10    object
#  o3      object
#  no2     object
#  so2     object
#  co      object
# dtype: object

# %%
# อ่านไฟล์ข้อมูลใหม่ โดยระบุชื่อคอลัมน์ที่มีประเภทข้อมูลเป็น date

df = pd.read_csv(url, parse_dates=['date'])

# %%
# ตรวจสอบ data types จะพบว่า คอลัมน์ date ถูกมองว่า date-time ถูกต้อง แต่ คอลัมภ์ pm25 ยังถูกมองเป็น string อยู่

df.dtypes
# Out:
# date     datetime64[ns]
#  pm25            object
#  pm10            object
#  o3              object
#  no2             object
#  so2             object
#  co              object
# dtype: object

# %%
# แปลงประเภทข้อมูลของคอลัมภ์ pm25 ให้เป็น numeric

df['pm25'] = pd.to_numeric(df[' pm25'], errors='coerce')

# %%
# สร้าง dataframe ใหม่ ให้มีเฉพาะคอลัมน์ที่ต้องการ คือ คอลัมน์เวลา และค่าที่เราต้องการพยากรณ์

df_pm25 = df[['date', 'pm25']]

# %%
# plot graph

df_pm25.set_index("date").plot(title='PM2.5 Concentration', grid=True, figsize=(20,10))
# Out:
# <Axes: title={'center': 'PM2.5 Concentration'}, xlabel='date'>

# %%
# ใน prophet จะอ่านจากชื่อคอลัมน์ว่า อันไหนเป็น เวลา อันไหนเป็น ค่าที่ต้องพยากรณ์ โดยต้องตั้ง ให้เป็นชื่อว่า ds และ y ตามลำดับ

df_pm25 = df_pm25.rename(columns={'date': 'ds', 'pm25': 'y'})

df_pm25.tail()
# Out:
#              ds   y
# 2961 2015-03-15 NaN
# 2962 2014-11-30 NaN
# 2963 2013-12-31 NaN
# 2964 2014-01-26 NaN
# 2965 2016-01-01 NaN

# %%
# หาวันสุดท้ายที่มีข้อมูลใน data ของเรา

df_pm25['ds'].max()
# Out:
# Timestamp('2022-02-19 00:00:00')

# %%
# สร้าง model สำหรับการทำนาย

my_model = Prophet(interval_width=0.95)

# %%
# train model จากข้อมูลเก่า

my_model.fit(df_pm25)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# สร้าง dataframe สำหรับวันในอดีตและอนาคตที่ต้องการทำนาย

future_dates = my_model.make_future_dataframe(periods=7)
future_dates.tail(7)
# Out:
#              ds
# 2966 2022-02-20
# 2967 2022-02-21
# 2968 2022-02-22
# 2969 2022-02-23
# 2970 2022-02-24
# 2971 2022-02-25
# 2972 2022-02-26

# %%
# พยากรณ์ข้อมูล

forecast = my_model.predict(future_dates)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds       yhat  yhat_lower  yhat_upper
# 2968 2022-02-22  92.217778   50.307115  131.449290
# 2969 2022-02-23  91.280434   49.582934  129.420593
# 2970 2022-02-24  89.004797   47.741135  128.821816
# 2971 2022-02-25  87.137100   44.483024  125.648736
# 2972 2022-02-26  86.427654   43.312670  126.257573

# %%
# แสดงผลการพยากรณ์

fig1 = my_model.plot(forecast)

# %%
# แสดงผลองค์ประกอบ trend และ seasonal pattern

fig2 = my_model.plot_components(forecast)

# %%
# รวมค่าจริงและค่าพยากรณ์เพื่อนำไปคำนวณหาค่าความแม่นยำ

df_merge = pd.merge(df_pm25, forecast[['ds','yhat_lower','yhat_upper','yhat']],on='ds')
df_merge = df_merge[['ds','yhat_lower','yhat_upper','yhat','y']]
df_merge.head()
# Out:
#           ds  yhat_lower  yhat_upper        yhat     y
# 0 2022-02-01   67.202285  146.732042  106.557375  68.0
# 1 2022-02-02   67.013614  149.589329  105.802069  58.0
# 2 2022-02-03   63.337587  144.016625  103.742395  66.0
# 3 2022-02-04   62.031044  141.159846  102.136129  73.0
# 4 2022-02-05   56.993338  140.549536  101.741879  94.0

# %% [markdown]
# # Cross Validation

# %%
# ทำการ cross validation การทำนายผล

from prophet.diagnostics import cross_validation

df_cv = cross_validation(my_model, initial='1820 days', period='10 days', horizon = '10 days')
# Out:
# INFO:prophet:Making 21 forecasts with cutoffs between 2021-07-24 00:00:00 and 2022-02-09 00:00:00
#   0%|          | 0/21 [00:00<?, ?it/s]

# %%
# แสดงผลการ cross validation

df_cv.head()
# Out:
#           ds       yhat  yhat_lower  yhat_upper     y     cutoff
# 0 2021-07-25  51.000369   12.500158   90.499893  44.0 2021-07-24
# 1 2021-07-26  52.603108   12.616245   97.298905  48.0 2021-07-24
# 2 2021-07-27  53.400066   11.623172   94.501486  40.0 2021-07-24
# 3 2021-07-28  53.171267   13.694541   91.996229  45.0 2021-07-24
# 4 2021-07-29  51.539344   14.249314   91.061389  44.0 2021-07-24

# %%
# คำนวณหาค่าความแม่นยำ

from prophet.diagnostics import performance_metrics

df_p = performance_metrics(df_cv)
df_p.head()
# Out:
#   horizon         mse       rmse        mae      mape     mdape     smape  \
# 0  1 days  604.590282  24.588418  19.166522  0.362945  0.243609  0.266794
# 1  2 days  603.956124  24.575519  19.550308  0.322362  0.317749  0.260611
# 2  3 days  561.978322  23.706082  19.428842  0.389149  0.229071  0.283846
# 3  4 days  400.489004  20.012221  14.775910  0.260246  0.159114  0.205055
# 4  5 days  378.511502  19.455372  16.196555  0.258270  0.171349  0.218606
#
#    coverage
# 0  0.857143
# 1  0.952381
# 2  0.857143
# 3  0.952381
# 4  1.000000

# %%
# แสดงผลความแม่นยำ

from prophet.plot import plot_cross_validation_metric

fig = plot_cross_validation_metric(df_cv, metric='mape')
# Out:
# /usr/local/lib/python3.12/dist-packages/prophet/plot.py:547: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt = df_none['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])
# /usr/local/lib/python3.12/dist-packages/prophet/plot.py:548: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   x_plt_h = df_h['horizon'].astype('timedelta64[ns]').view(np.int64) / float(dt_conversions[i])

# %% [markdown]
# # Tuning Prophet Model

# %% [markdown]
# ในการสร้าง Prophet Model นั้น เราสามารถปรับแต่งค่า parameter ต่างๆ รวมถึงเพิ่ม regressor เข้าไปใน Model เพื่อช่วยในการทำนาย

# %% [markdown]
# ## Trend - Parameter Tuning

# %% [markdown]
# หากเรามีข้อมูลอนุกรมเวลายาว อาจเป็นไปได้ว่ามีการเปลี่ยนแปลง Trend ในช่วงเวลา เช่น บางช่วง Trend เติบโตมาก บางช่วงเป็น Trend ขาลง
#
# เราจะทำการปรับค่า changepoint_prior_scale เพื่อให้ Prophet สามารถตรวจพบการเปลี่ยนแปลงที่เกิดขึ้นได้ด้วยตัวเอง
#
# ยิ่งใส่ค่า changepoint_prior_scale มากขึ้น จะยิ่งตรวจพบการเปลี่ยนแปลงมากขึ้น

# %%
# set changepoint_prior_scale=0.1

my_model_trend_change = Prophet(changepoint_prior_scale=0.1)
my_model_trend_change.fit(df_pm25)
forecast = my_model_trend_change.predict(future_dates)
fig1 = my_model_trend_change.plot(forecast)
a = add_changepoints_to_plot(fig1.gca(), my_model_trend_change, forecast)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# set changepoint_prior_scale=10

my_model_trend_change = Prophet(changepoint_prior_scale=10)
my_model_trend_change.fit(df_pm25)
forecast = my_model_trend_change.predict(future_dates)
fig1 = my_model_trend_change.plot(forecast)
a = add_changepoints_to_plot(fig1.gca(), my_model_trend_change, forecast)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# ## Seasonal - Parameter Tuning

# %% [markdown]
# นอกเหนือจากการเปลี่ยนแปลง Trend แล้ว อาจมีการเปลี่ยนแปลงของ Seasonal ได้ด้วย
#
# เราจะทำการปรับค่า seasonality_prior_scale เพื่อให้ Prophet สามารถตรวจพบการเปลี่ยนแปลงที่เกิดขึ้นได้ด้วยตัวเอง
#
# ยิ่งใส่ค่า seasonality_prior_scale มากขึ้น จะยิ่งตรวจพบการเปลี่ยนแปลงมากขึ้น

# %%
# set seasonality_prior_scale=0.1

my_model_seasonal_change = Prophet(seasonality_prior_scale=0.1)
my_model_seasonal_change.fit(df_pm25)
forecast = my_model_seasonal_change.predict(future_dates)
fig1 = my_model_seasonal_change.plot_components(forecast)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# set seasonality_prior_scale=10

my_model_seasonal_change = Prophet(seasonality_prior_scale=10)
my_model_seasonal_change.fit(df_pm25)
forecast = my_model_seasonal_change.predict(future_dates)
fig1 = my_model_seasonal_change.plot_components(forecast)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# # สร้าง Pipeline เพื่อทำ hyperparameter tuning

# %%
import itertools

param_grid = {
    'changepoint_prior_scale': [0.1, 1, 5],
    'seasonality_prior_scale': [0.1, 1, 5],
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
mape = []  # Store the MAPE for each params here

# Use cross validation to evaluate all parameters
for params in all_params:
    m = Prophet(**params).fit(df_pm25)  # Fit model with given params
    df_cv = cross_validation(m, initial='1820 days', period='10 days', horizon = '10 days')
    df_p = performance_metrics(df_cv, rolling_window=1)
    mape.append(df_p['mape'].values[0])

# Find the best parameters
tuning_results = pd.DataFrame(all_params)
tuning_results['mape'] = mape
print(tuning_results)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Making 21 forecasts with cutoffs between 2021-07-24 00:00:00 and 2022-02-09 00:00:00
#   0%|          | 0/21 [00:00<?, ?it/s]
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Making 21 forecasts with cutoffs between 2021-07-24 00:00:00 and 2022-02-09 00:00:00
#   0%|          | 0/21 [00:00<?, ?it/s]
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Making 21 forecasts with cutoffs between 2021-07-24 00:00:00 and 2022-02-09 00:00:00
#   0%|          | 0/21 [00:00<?, ?it/s]
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Making 21 forecasts with cutoffs between 2021-07-24 00:00:00 and 2022-02-09 00:00:00
#   0%|          | 0/21 [00:00<?, ?it/s]
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Making 21 forecasts with cutoffs between 2021-07-24 00:00:00 and 2022-02-09 00:00:00
#   0%|          | 0/21 [00:00<?, ?it/s]
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Making 21 forecasts with cutoffs between 2021-07-24 00:00:00 and 2022-02-09 00:00:00
#   0%|          | 0/21 [00:00<?, ?it/s]
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Making 21 forecasts with cutoffs between 2021-07-24 00:00:00 and 2022-02-09 00:00:00
#   0%|          | 0/21 [00:00<?, ?it/s]
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Making 21 forecasts with cutoffs between 2021-07-24 00:00:00 and 2022-02-09 00:00:00
#   0%|          | 0/21 [00:00<?, ?it/s]
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Making 21 forecasts with cutoffs between 2021-07-24 00:00:00 and 2022-02-09 00:00:00
#   0%|          | 0/21 [00:00<?, ?it/s]
#    changepoint_prior_scale  seasonality_prior_scale      mape
# 0                      0.1                      0.1  0.275885
# 1                      0.1                      1.0  0.275929
# 2                      0.1                      5.0  0.275856
# 3                      1.0                      0.1  0.264479
# 4                      1.0                      1.0  0.264564
# 5                      1.0                      5.0  0.264083
# 6                      5.0                      0.1  0.259014
# 7                      5.0                      1.0  0.260065
# 8                      5.0                      5.0  0.260477

# %% [markdown]
# # Save และ Load Model

# %%
import json
from prophet.serialize import model_to_json, model_from_json

with open('prophet_model.json', 'w') as fout:
    json.dump(model_to_json(m), fout)  # Save model

# %%
with open('prophet_model.json', 'r') as fin:
    m = model_from_json(json.load(fin))  # Load model

# %% [markdown]
# # Checkpoint ท้ายบท

# %% [markdown]
# *   ☑️เข้าใจถึงองค์ประกอบของข้อมูลประเภทอนุกรมเวลา
# *   ☑️สร้าง Forecasting Model เพื่อใช้ทำนายข้อมูลในอนาคตได้
